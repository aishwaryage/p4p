# %% [markdown]
# <a href="https://colab.research.google.com/github/aishwaryage/p4p/blob/main/week1/Project1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Project 1:

# %%
import numpy as np
import math
import matplotlib.pyplot as plt

# %%
def sqrt(x): return np.sqrt(x)

# %% [markdown]
# Listing all the general projectile equations first.
#
# $x=x0+v^o_xt+1/2a_xt^2$
#
# $y=yo+v^o_yt+1/2a_yt^2$
#
# $v_x=v^o_x + a_xt$
#
# $v_y = v^o_y + a_yt$

# %% [markdown]
# Specific to a projectile under gravity :
# $a_x=0; a_y=-g$
#
# $x=x_o+v_xt$
#
# $y=y_o+v_yt-gt^2/2$
#
# $v_x=v^o_x$
#
# $v_y= v^o_y-gt $
#
# $v_y^2= (v^o_y)^2 -2g(y-y_o) $
#
# $y = y_o +1/2(v^o_y+v_y)t$

# %% [markdown]
# Step 1: write a function function for a 1D position as a function of time and initial
# conditions [for constant acceleration].

# %%
def x(t): return (x_0 + vx_0*t + (ax_0*t**2)*0.5 )

# %% [markdown]
# Step 2: write a function function for a 1D velocity as a function of time and initial
# conditions [for constant acceleration].

# %%
def vx(t): return (vx_0 + ax_0*t)

# %% [markdown]
# Step 3: Fixing $a_y = 9.8  m/s^2 $and $a_x=0$, write code for plotting the $x, y, v_x, v_y$ as a
# function of time, given some initial values for $x, y, v_x, v_y$.

# %%
def draw_one_d(t, f):
  plt.plot(t, f)
  plt.xlabel('Time')
  plt.ylabel(f'{entity}')
  plt.title(f'{entity} as a function of time')
  plt.show()
t = np.arange(0.0, 3.0, 0.001)

# %%
x_0 = 0
vx_0 = 10
ax_0 = 0
y_0 = 0
vy_0 = 10
ay_0 = -9.8

# %%
def y(t): return (y_0 + vy_0*t + 0.5*(ay_0*t**2) )
def vy(t): return (vy_0 + ay_0*t)

# %% [markdown]
# X(t)

# %%
entity = 'x'
plt.subplot(212)
draw_one_d(t, x(t))

# %% [markdown]
# y(t)

# %%
entity = 'y'
draw_one_d(t, y(t))
print(y(10/9.8))
# Out:
# 5.10204081632653

# %% [markdown]
# $V_x$(t)

# %%
entity = '$v_x$'
draw_one_d(t, vx(t))

# %% [markdown]
# $V_y(t)$

# %%
entity = '$v_y$'
draw_one_d(t, vy(t))

# %% [markdown]
# Y as f(X)

# %%
plt.plot(x(t), y(t))
plt.xlabel('x-position')
plt.ylabel('y-position')
plt.title('Y as a function of X')
# Out:
# Text(0.5, 1.0, 'Y as a function of X')
